# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from faker import Faker

# 显示中文标签
plt.style.use('seaborn')
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # XX市公安治安防控项目案例
#
# 项目简介：本项目建设是XX市公安局站在贯彻理解国家整体安全观的历史新高度，深刻认识大数据、人工智能等信息化产业发展的趋势规律和重大作用，准确把握新时代公安工作面临的新形势、新任务、新要求，紧紧抓住信息科技前沿技术加速发展的新机遇，持续推进公安系统改革和警务模式创新的战略选择和重要举措。着力解决防控体系建设工作碎片化、数据孤岛化等问题，通过利旧或新建物联感知设施、设备，推进智能感知、智能采集等信息化科技手段应用，建设社会治安防控业务应用系统，实现重点领域、重点区域信息化管理、智能化应用，推动警务模式和警务机制转型升级。
#
# 防控项目总览：包含公交地铁防控系统、街面巡防管控系统、安防小区管控系统、娱乐场所治安管控系统、公安检查站管控系统、社会基础信息管理系统等等
#
# 在这里，我们主要演示社会基础信息管理系统。

# %% [markdown]
# # 社会基础信息管理系统
#
# 社会基础信息管理系统主要目的是全面摸清辖区实有人口、实有房屋、实有单位的基本情况，建立完整、准确的基础信息数据库。这有助于公安加强基础信息建设，有效服务和支撑反恐防暴、侦查破案、行政管理、服务群众等各项公安工作。
#
# 社会基础信息管理系统主要分为3个子项目：
# * 实有人口分析：实现对人口从多维度进行展现，范围包含人口概览、人员来源占比、高龄老人数据分析、重点人员等维度。
#
#
# * 实有房屋分析：实现对房屋从多维度进行展现，范围包含自住房屋、出租房屋、空置房屋、单位房屋等。
#
#
# * 实有单位分析：实现对单位信息从多维度进行展现，范围包含企业单位、事业单位、机关单位、医院、宾馆、领事馆等等。
#
# 接下来我们以实有人口分析举例说明：

# %% [markdown]
# ## 实有人口分析
#
# 实现对人口从多维度进行展现，范围包含人口概览、人员来源占比、高龄老人数据分析、重点人员等维度。
#
# * 总人口概览：从户籍人员、外来人员两个维度分析所占总人口的百分比等信息。
# * 外来人员: 统计展现外来人员前五名地区等信息。
# * 年龄分布：实现对辖区人口年龄信息进行分析。
# * 重点人员：针对某个重点人员判断是否属于涉恐人员、涉稳人员、重大刑事犯罪前科人员、涉毒人员、在逃人员、肇事肇祸精神病人、重点上访人员等等。

# %% [markdown]
# ### 1 构造数据
#
# 我们根据业务理解构造一份实有人口的数据，数据字段包含：姓名、性别、身份证、生日、户籍地、公司名、职位、电话、现住址。

# %%
# 构造数据
fake = Faker(locale='zh_CN')

temp = []
for i in range(100000):
    res = fake.profile(fields=['name', 'sex', 'ssn',
                               'birthdate', 'company', 'job'])
    res['电话'] = fake.phone_number()
    res['现住址'] = '北京市{}'.format(fake.street_address())
    res['户籍城市'] = fake.city_name() 
    temp.append(res)

data = pd.DataFrame(temp)
data.rename(columns={'job': '职位','name':'姓名', 'sex': '性别', 'ssn': '身份证',
            'birthdate': '生日', 'company': '公司'},inplace=True)

# 去重复
data.drop_duplicates(subset=['身份证'],keep='first',inplace=True)
data
# Out:
#                         职位           公司                 身份证   姓名 性别  \
# 0                投资/基金项目经理     昊嘉传媒有限公司  500236199611197268   余健  F
# 1                通信技术开发及应用   商软冠联科技有限公司  440507197906289564  刘玉英  M
# 2                    项目工程师     海创网络有限公司  350423197709162786   薛云  F
# 3                    财务分析员  MBP软件网络有限公司  231282198104019108   李倩  F
# 4      首席技术执行官CTO/首席信息官CIO   方正科技网络有限公司  610427196210267225   王琴  M
# ...                    ...          ...                 ...  ... ..
# 99995              销售行政及商务   商软冠联信息有限公司  542223195005042038   孔建  F
# 99996                 物流主管     思优信息有限公司  130322194110024700  陈淑英  M
# 99997                   刨工     太极网络有限公司  440114199702128815   余琴  M
# 99998                 媒介主管     思优网络有限公司  130406193612247198   路成  M
# 99999                集装箱业务     九方传媒有限公司  451100196402140848  林红梅  F
#
#                生日           电话         现住址 户籍城市
# 0      1985-12-17  14752054279    北京市武汉街o座   北京
# 1      1952-03-30  13033653586     北京市郁路H座   惠州
# 2      1987-05-18  18250005982     北京市王路S座   香港
# 3      1985-12-22  14584697311    北京市巢湖路u座   汕尾
# 4      2019-09-09  15796588647     北京市董路H座   辛集
# ...           ...          ...         ...  ...
# 99995  1992-02-25  13150390480     北京市林路s座  六盘水
# 99996  1971-07-15  13083452291  北京市齐齐哈尔路N座   嘉禾
# 99997  1956-01-18  13460653032     北京市王路W座   福州
# 99998  1965-09-06  13498725999     北京市甄街X座   南宁
# 99999  1984-01-20  18983128808     北京市潘路e座   大冶
#
# [100000 rows x 9 columns]

# %% [markdown]
# 然后我们在构建一张表来存储重点人员，字段包含是否属于涉恐人员、涉稳人员、重大刑事犯罪前科人员、涉毒人员、在逃人员、肇事肇祸精神病人、重点上访人员等等，在这里就简要以1和0分别代表是和否。

# %%
# 构建一张重点人员表
important_people = []

# 随机抽取上面的人作为重点人员
for i in range(100):
    res = {}
    res['身份证'] = np.random.choice(data['身份证'])
    res['涉恐人员'] = np.random.choice([0,1],p=[0.9, 0.1])
    res['涉稳人员'] = np.random.choice([0,1],p=[0.9, 0.1])
    res['重大刑事犯罪前科人员'] = np.random.choice([0,1],p=[0.9, 0.1])
    res['涉毒人员'] = np.random.choice([0,1],p=[0.9, 0.1])
    res['在逃人员'] = np.random.choice([0,1],p=[0.9, 0.1])
    res['肇事肇祸精神病人'] = np.random.choice([0,1],p=[0.9, 0.1])
    res['重点上访人员'] = np.random.choice([0,1],p=[0.1, 0.9])
    
    # 若7类重点人员都是0，那么就把重点上访人员设为1
    count = 0
    for value in res.values():
        if value == 1:
            break
        else:
            count += 1
            
    if count == 7:
        res['重点上访人员'] = 1
    
    important_people.append(res)

important_people_data = pd.DataFrame(important_people)
important_people_data.drop_duplicates(subset=['身份证'],keep='first',inplace=True)
important_people_data
# Out:
#                    身份证  涉恐人员  涉稳人员  重大刑事犯罪前科人员  涉毒人员  在逃人员  肇事肇祸精神病人  重点上访人员
# 0   421083195508302943     0     0           1     0     0         1       1
# 1   46902319501031200X     0     0           0     0     0         0       1
# 2   520201199712171976     0     0           0     0     0         0       1
# 3   450802199111248713     0     1           0     0     0         0       0
# 4   32030120010729877X     0     0           0     0     0         0       1
# ..                 ...   ...   ...         ...   ...   ...       ...     ...
# 95  620103198510315587     0     0           0     0     0         1       1
# 96  340600200103273616     0     1           0     1     0         0       1
# 97  542424197608113129     0     0           0     0     1         0       1
# 98  411621194112036076     0     0           0     0     0         0       1
# 99  370124198212030452     0     0           1     0     0         0       1
#
# [100 rows x 8 columns]

# %% [markdown]
# ### 2 数据分析
#
# 假如我们上面构成的数据是北京某辖区的实有人口数据，现在想要对该辖区的实有人口从多维度进行分析，包含总人口概览、外来人员、户籍属性分类统计、年龄分布、重点人员。

# %% [markdown]
# #### 2.1 总人口概览
# 从户籍人员、外来人员两个维度分析所占总人口的百分比等信息。

# %%
# 显示数据
data.head()
# Out:
#                     职位           公司                 身份证   姓名 性别          生日  \
# 0            投资/基金项目经理     昊嘉传媒有限公司  500236199611197268   余健  F  1985-12-17
# 1            通信技术开发及应用   商软冠联科技有限公司  440507197906289564  刘玉英  M  1952-03-30
# 2                项目工程师     海创网络有限公司  350423197709162786   薛云  F  1987-05-18
# 3                财务分析员  MBP软件网络有限公司  231282198104019108   李倩  F  1985-12-22
# 4  首席技术执行官CTO/首席信息官CIO   方正科技网络有限公司  610427196210267225   王琴  M  2019-09-09
#
#             电话       现住址 户籍城市
# 0  14752054279  北京市武汉街o座   北京
# 1  13033653586   北京市郁路H座   惠州
# 2  18250005982   北京市王路S座   香港
# 3  14584697311  北京市巢湖路u座   汕尾
# 4  15796588647   北京市董路H座   辛集

# %%
# 判断是否为户籍人员，1为是，0为否
data['户籍人员'] = np.where(data['户籍城市'] == '北京', 1, 0)
data.head()
# Out:
#                     职位           公司                 身份证   姓名 性别          生日  \
# 0            投资/基金项目经理     昊嘉传媒有限公司  500236199611197268   余健  F  1985-12-17
# 1            通信技术开发及应用   商软冠联科技有限公司  440507197906289564  刘玉英  M  1952-03-30
# 2                项目工程师     海创网络有限公司  350423197709162786   薛云  F  1987-05-18
# 3                财务分析员  MBP软件网络有限公司  231282198104019108   李倩  F  1985-12-22
# 4  首席技术执行官CTO/首席信息官CIO   方正科技网络有限公司  610427196210267225   王琴  M  2019-09-09
#
#             电话       现住址 户籍城市  户籍人员
# 0  14752054279  北京市武汉街o座   北京     1
# 1  13033653586   北京市郁路H座   惠州     0
# 2  18250005982   北京市王路S座   香港     0
# 3  14584697311  北京市巢湖路u座   汕尾     0
# 4  15796588647   北京市董路H座   辛集     0

# %%
# 查看数量
count = data['户籍人员'].value_counts()
count
# Out:
# 0    98544
# 1     1456
# Name: 户籍人员, dtype: int64

# %%
# 画出饼图
plt.pie(count,labels=['外来人员','户籍人员'],autopct='%.2f',textprops={'fontsize':15})
plt.title('总人口概览',fontsize=15)
# Out:
# Text(0.5, 1.0, '总人口概览')

# %% [markdown]
# 我们可以得到信息，该辖区的外来人员占比十分高，几乎全部为外来人员。

# %% [markdown]
# #### 2.2 外来人员
#
# 统计展现外来人员前五名地区等信息。

# %%
# 得出外来人员的前5名
migrants = data[data['户籍人员']==0]
migrants['户籍城市'].value_counts()[:5]
# Out:
# 哈尔滨    2884
# 太原     2826
# 沈阳     2812
# 西宁     1532
# 潮州     1492
# Name: 户籍城市, dtype: int64

# %% [markdown]
# #### 2.3 年龄分布
#
# 实现对辖区人口年龄信息进行分析,可以分析老年化的程度或者青壮年的百分比等等。

# %%
# 得到今年的时间
today = datetime.datetime.today().year

# 算出年龄
data['生日'] = pd.to_datetime(data['生日'])
data['年龄'] = today - data['生日'].dt.year
data.head()
# Out:
#                     职位           公司                 身份证   姓名 性别         生日  \
# 0            投资/基金项目经理     昊嘉传媒有限公司  500236199611197268   余健  F 1985-12-17
# 1            通信技术开发及应用   商软冠联科技有限公司  440507197906289564  刘玉英  M 1952-03-30
# 2                项目工程师     海创网络有限公司  350423197709162786   薛云  F 1987-05-18
# 3                财务分析员  MBP软件网络有限公司  231282198104019108   李倩  F 1985-12-22
# 4  首席技术执行官CTO/首席信息官CIO   方正科技网络有限公司  610427196210267225   王琴  M 2019-09-09
#
#             电话       现住址 户籍城市  户籍人员  年龄
# 0  14752054279  北京市武汉街o座   北京     1  37
# 1  13033653586   北京市郁路H座   惠州     0  70
# 2  18250005982   北京市王路S座   香港     0  35
# 3  14584697311  北京市巢湖路u座   汕尾     0  37
# 4  15796588647   北京市董路H座   辛集     0   3

# %%
# 对年龄进行分组
bins = [0,14,59,120]
p_counts = pd.cut(data['年龄'],bins)

# 查看每个区间变量的个数
p_counts.value_counts()
# Out:
# (59, 120]    49101
# (14, 59]     38514
# (0, 14]      12124
# Name: 年龄, dtype: int64

# %%
sns.countplot(x=p_counts.index,data=p_counts)

# %% [markdown]
# #### 2.4 重点人员
#
# 针对某个重点人员判断是否属于涉恐人员、涉稳人员、重大刑事犯罪前科人员、涉毒人员、在逃人员、肇事肇祸精神病人、重点上访人员等等。在实际业务中，这些信息因为涉密并隶属于不同部门，所以会储存在不同的表中，而我们需要做的便是数据聚合，并整理出一张重点人员表。

# %%
# 经过数据聚合形成的重点人员表
important_people_data
# Out:
#                    身份证  涉恐人员  涉稳人员  重大刑事犯罪前科人员  涉毒人员  在逃人员  肇事肇祸精神病人  重点上访人员
# 0   421083195508302943     0     0           1     0     0         1       1
# 1   46902319501031200X     0     0           0     0     0         0       1
# 2   520201199712171976     0     0           0     0     0         0       1
# 3   450802199111248713     0     1           0     0     0         0       0
# 4   32030120010729877X     0     0           0     0     0         0       1
# ..                 ...   ...   ...         ...   ...   ...       ...     ...
# 95  620103198510315587     0     0           0     0     0         1       1
# 96  340600200103273616     0     1           0     1     0         0       1
# 97  542424197608113129     0     0           0     0     1         0       1
# 98  411621194112036076     0     0           0     0     0         0       1
# 99  370124198212030452     0     0           1     0     0         0       1
#
# [100 rows x 8 columns]

# %% [markdown]
# 假设公安排查出某人的形迹可疑，上去询问身份证号，在数据库里检索，就可排查出是否为重点人员。

# %%
# 筛选出嫌疑人信息
people = ['620103198510315587','440507197906289564']
important_people_data[important_people_data['身份证'].isin(people)]
# Out:
#                    身份证  涉恐人员  涉稳人员  重大刑事犯罪前科人员  涉毒人员  在逃人员  肇事肇祸精神病人  重点上访人员
# 95  620103198510315587     0     0           0     0     0         1       1
